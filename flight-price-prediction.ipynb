# %% [markdown]
# <a id = '5.5'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>Flight Price Prediction</strong></p>

# %%
#importing libraries
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing dataset
# 1.Since data is in form of excel file we have to use pandas read_excel to load the data.
# 2.After loading it is important to check null values in a column or a row
# 3.If it is present then following can be done,
# *       Filling NaN values with mean, median and mode using fillna() method
# *       If Less missing values, we can drop it as well

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\datamites\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\datamites\anaconda3\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Datamites\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Datamites\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Datamites\anaconda3\Lib\site-packages)

# %%
#importing data
df=pd.read_excel('Data_Train.xlsx')
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.info()   #information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
#describe about the data
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df.shape
# Out:
# (10683, 11)

# %%
#finding the null values
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in c:\users\datamites\anaconda3\lib\site-packages (from missingno) (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\datamites\anaconda3\lib\site-packages (from missingno) (3.10.9)
# Requirement already satisfied: scipy in c:\users\datamites\anaconda3\lib\site-packages (from missingno) (1.16.3)
# Requirement already satisfied: seaborn in c:\users\datamites\anaconda3\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\datamites\anaconda3\lib\site-packages (from matplotlib->missingno) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\datamites\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\datamites\anaconda3\lib\site-packages (from matplotlib->missingno) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\datamites\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\datamites\anaconda3\lib\site-packages (from matplotlib->missingno) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\datamites\anaconda3\lib\site-packages (from matplotlib->missingno) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\datamites\anaconda3\lib\site-packages (from matplotlib->missingno) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\datamites\anaconda3\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\datamites\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\datamites\anaconda3\lib\site-packages (from seaborn->missingno) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\datamites\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\datamites\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Datamites\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Datamites\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Datamites\anaconda3\Lib\site-packages)

# %%
import missingno as msno
msno.bar(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### **We observe 2 missing values,I can directly drop these,as these are very less.**

# %%
#drop the nullvalues
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# <a id = '5.5'></a>
# <p style = "font-size : 25px; color : 'blue' ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>Data Cleaning</strong></p>

# %%
df.dtypes # datatypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# #### The datatypes of Date_of_journey,Arrival_Time and Dep_Time is object.So,firstly we convert it into date and time for proper predicion.
#
# **dt.day method will extract only day of that date
# dt.month method will extract only month of that date**

# %%
def change_into_datetime(col):
    df[col]=pd.to_datetime(df[col])

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
for i in ['Date_of_Journey','Dep_Time', 'Arrival_Time']:
    change_into_datetime(i)

# %%
df.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time       datetime64[ns]
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %% [markdown]
# ##### Now ,we extract day and month from Date_of_journey and stored in 2 other columns.
# ##### Then there will be no use of 'Date_of_Journey' column,so we drop it.

# %%
df['journey_day']=df['Date_of_Journey'].dt.day
df['journey_month']=df['Date_of_Journey'].dt.month

# %%
df.head(10)
# Out:
#              Airline Date_of_Journey    Source Destination  \
# 0             IndiGo      2019-03-24  Banglore   New Delhi
# 1          Air India      2019-05-01   Kolkata    Banglore
# 2        Jet Airways      2019-06-09     Delhi      Cochin
# 3             IndiGo      2019-05-12   Kolkata    Banglore
# 4             IndiGo      2019-03-01  Banglore   New Delhi
# 5           SpiceJet      2019-06-24   Kolkata    Banglore
# 6        Jet Airways      2019-03-12  Banglore   New Delhi
# 7        Jet Airways      2019-03-01  Banglore   New Delhi
# 8        Jet Airways      2019-03-12  Banglore   New Delhi
# 9  Multiple carriers      2019-05-27     Delhi      Cochin
#
#                    Route            Dep_Time        Arrival_Time Duration  \
# 0              BLR → DEL 2026-06-22 22:20:00 2026-03-22 01:10:00   2h 50m
# 1  CCU → IXR → BBI → BLR 2026-06-22 05:50:00 2026-06-22 13:15:00   7h 25m
# 2  DEL → LKO → BOM → COK 2026-06-22 09:25:00 2026-06-10 04:25:00      19h
# 3        CCU → NAG → BLR 2026-06-22 18:05:00 2026-06-22 23:30:00   5h 25m
# 4        BLR → NAG → DEL 2026-06-22 16:50:00 2026-06-22 21:35:00   4h 45m
# 5              CCU → BLR 2026-06-22 09:00:00 2026-06-22 11:25:00   2h 25m
# 6        BLR → BOM → DEL 2026-06-22 18:55:00 2026-03-13 10:25:00  15h 30m
# 7        BLR → BOM → DEL 2026-06-22 08:00:00 2026-03-02 05:05:00   21h 5m
# 8        BLR → BOM → DEL 2026-06-22 08:55:00 2026-03-13 10:25:00  25h 30m
# 9        DEL → BOM → COK 2026-06-22 11:25:00 2026-06-22 19:15:00   7h 50m
#
#   Total_Stops              Additional_Info  Price  journey_day  journey_month
# 0    non-stop                      No info   3897           24              3
# 1     2 stops                      No info   7662            1              5
# 2     2 stops                      No info  13882            9              6
# 3      1 stop                      No info   6218           12              5
# 4      1 stop                      No info  13302            1              3
# 5    non-stop                      No info   3873           24              6
# 6      1 stop  In-flight meal not included  11087           12              3
# 7      1 stop                      No info  22270            1              3
# 8      1 stop  In-flight meal not included  11087           12              3
# 9      1 stop                      No info   8625           27              5

# %%
df.drop('Date_of_Journey', axis=1, inplace=True)

# %% [markdown]
# ##### From Arrival_time and Dept_time features,we extract hour and minutes and stored in new columns and drop these columns

# %%
# function for extracting hour and minutes
def extract_hour(data,col):
    data[col+'_hour']=data[col].dt.hour
    
def extract_min(data,col):
    data[col+'_min']=data[col].dt.minute
    

def drop_col(data,col):
    data.drop(col,axis=1,inplace=True)

# %%
#call the function
# Departure time is when a plane leaves the gate. 
# Similar to Date_of_Journey we can extract values from Dep_Time
extract_hour(df,'Dep_Time')

#extracting minutes
extract_min(df,'Dep_Time')

#drop the column
drop_col(df,'Dep_Time')

# %%
#extracting hour
extract_hour(df,'Arrival_Time')

#extracting min
extract_min(df,'Arrival_Time')


#drop the column
drop_col(df,'Arrival_Time')

# %%
df.head(10)
# Out:
#              Airline    Source Destination                  Route Duration  \
# 0             IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1          Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2        Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3             IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4             IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# 5           SpiceJet   Kolkata    Banglore              CCU → BLR   2h 25m
# 6        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL  15h 30m
# 7        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL   21h 5m
# 8        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL  25h 30m
# 9  Multiple carriers     Delhi      Cochin        DEL → BOM → COK   7h 50m
#
#   Total_Stops              Additional_Info  Price  journey_day  journey_month  \
# 0    non-stop                      No info   3897           24              3
# 1     2 stops                      No info   7662            1              5
# 2     2 stops                      No info  13882            9              6
# 3      1 stop                      No info   6218           12              5
# 4      1 stop                      No info  13302            1              3
# 5    non-stop                      No info   3873           24              6
# 6      1 stop  In-flight meal not included  11087           12              3
# 7      1 stop                      No info  22270            1              3
# 8      1 stop  In-flight meal not included  11087           12              3
# 9      1 stop                      No info   8625           27              5
#
#    Dep_Time_hour  Dep_Time_min  Arrival_Time_hour  Arrival_Time_min
# 0             22            20                  1                10
# 1              5            50                 13                15
# 2              9            25                  4                25
# 3             18             5                 23                30
# 4             16            50                 21                35
# 5              9             0                 11                25
# 6             18            55                 10                25
# 7              8             0                  5                 5
# 8              8            55                 10                25
# 9             11            25                 19                15

# %% [markdown]
# ##### Lets Apply pre-processing on duration column,Separate Duration hours and minute from duration

# %%
duration=list(df['Duration'])
for i in range(len(duration)):
    if len(duration[i].split(' '))==2:
        pass
    else:
        if 'h' in duration[i]: # Check if duration contains only hour
             duration[i]=duration[i] + ' 0m' # Adds 0 minute
        else:
             duration[i]='0h '+ duration[i]

# %%
df['Duration']=duration

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK   19h 0m
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price  journey_day  journey_month  \
# 0    non-stop         No info   3897           24              3
# 1     2 stops         No info   7662            1              5
# 2     2 stops         No info  13882            9              6
# 3      1 stop         No info   6218           12              5
# 4      1 stop         No info  13302            1              3
#
#    Dep_Time_hour  Dep_Time_min  Arrival_Time_hour  Arrival_Time_min
# 0             22            20                  1                10
# 1              5            50                 13                15
# 2              9            25                  4                25
# 3             18             5                 23                30
# 4             16            50                 21                35

# %%
def hour(x):
    return x.split(' ')[0][0:-1]

def minutes(x):
    return x.split(' ')[1][0:-1]

# %%
df['dur_hour']=df['Duration'].apply(hour)

# %%
df['dur_min']=df['Duration'].apply(minutes)

# %%
df.head(10)
# Out:
#              Airline    Source Destination                  Route Duration  \
# 0             IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1          Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2        Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK   19h 0m
# 3             IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4             IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# 5           SpiceJet   Kolkata    Banglore              CCU → BLR   2h 25m
# 6        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL  15h 30m
# 7        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL   21h 5m
# 8        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL  25h 30m
# 9  Multiple carriers     Delhi      Cochin        DEL → BOM → COK   7h 50m
#
#   Total_Stops              Additional_Info  Price  journey_day  journey_month  \
# 0    non-stop                      No info   3897           24              3
# 1     2 stops                      No info   7662            1              5
# 2     2 stops                      No info  13882            9              6
# 3      1 stop                      No info   6218           12              5
# 4      1 stop                      No info  13302            1              3
# 5    non-stop                      No info   3873           24              6
# 6      1 stop  In-flight meal not included  11087           12              3
# 7      1 stop                      No info  22270            1              3
# 8      1 stop  In-flight meal not included  11087           12              3
# 9      1 stop                      No info   8625           27              5
#
#    Dep_Time_hour  Dep_Time_min  Arrival_Time_hour  Arrival_Time_min dur_hour  \
# 0             22            20                  1                10        2
# 1              5            50                 13                15        7
# 2              9            25                  4                25       19
# 3             18             5                 23                30        5
# 4             16            50                 21                35        4
# 5              9             0                 11                25        2
# 6             18            55                 10                25       15
# 7              8             0                  5                 5       21
# 8              8            55                 10                25       25
# 9             11            25                 19                15        7
#
#   dur_min
# 0      50
# 1      25
# 2       0
# 3      25
# 4      45
# 5      25
# 6      30
# 7       5
# 8      30
# 9      50

# %%
drop_col(df,'Duration')

# %%
df.dtypes
# Out:
# Airline              object
# Source               object
# Destination          object
# Route                object
# Total_Stops          object
# Additional_Info      object
# Price                 int64
# journey_day           int32
# journey_month         int32
# Dep_Time_hour         int32
# Dep_Time_min          int32
# Arrival_Time_hour     int32
# Arrival_Time_min      int32
# dur_hour             object
# dur_min              object
# dtype: object

# %%
df['dur_hour'] = df['dur_hour'].astype(int)
df['dur_min'] = df['dur_min'].astype(int)

# %%
df.dtypes
# Out:
# Airline              object
# Source               object
# Destination          object
# Route                object
# Total_Stops          object
# Additional_Info      object
# Price                 int64
# journey_day           int32
# journey_month         int32
# Dep_Time_hour         int32
# Dep_Time_min          int32
# Arrival_Time_hour     int32
# Arrival_Time_min      int32
# dur_hour              int64
# dur_min               int64
# dtype: object

# %% [markdown]
# #### Finding the categorical value

# %%
column=[column for column in df.columns if df[column].dtype=='object']
column
# Out:
# ['Airline', 'Source', 'Destination', 'Route', 'Total_Stops', 'Additional_Info']

# %% [markdown]
# #### Finding the cntinuous value

# %%
continuous_col =[column for column in df.columns if df[column].dtype!='object']
continuous_col
# Out:
# ['Price',
#  'journey_day',
#  'journey_month',
#  'Dep_Time_hour',
#  'Dep_Time_min',
#  'Arrival_Time_hour',
#  'Arrival_Time_min',
#  'dur_hour',
#  'dur_min']

# %% [markdown]
# # Handling categorical data

# %% [markdown]
# ### We are using two main Encoding Techniques to covert Categorical data into some numerical format
#
# #### Nominal data -- Data that are not in any order -->one hot encoding
# #### ordinal data -- Data are in order --> labelEncoder

# %%
categorical = df[column]

# %%
categorical.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info
# 0         No info
# 1         No info
# 2         No info
# 3         No info
# 4         No info

# %%
categorical['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %% [markdown]
# ## Airline vs Price Analysis

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Airline',y='Price',data=df.sort_values('Price',ascending=False))
# Out:
# <Axes: xlabel='Airline', ylabel='Price'>

# %% [markdown]
# ### From graph we can see that Jet Airways Business have the highest Price., Apart from the first Airline almost all are having similar median

# %% [markdown]
# #### Perform Total_Stops vs Price Analysis

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Total_Stops',y='Price',data=df.sort_values('Price',ascending=False))
# Out:
# <Axes: xlabel='Total_Stops', ylabel='Price'>

# %%
# As Airline is Nominal Categorical data we will perform OneHotEncoding
Airline=pd.get_dummies(categorical['Airline'],drop_first=True)

# %%
Airline.head()
# Out:
#    Air India  GoAir  IndiGo  Jet Airways  Jet Airways Business  \
# 0      False  False    True        False                 False
# 1       True  False   False        False                 False
# 2      False  False   False         True                 False
# 3      False  False    True        False                 False
# 4      False  False    True        False                 False
#
#    Multiple carriers  Multiple carriers Premium economy  SpiceJet  Trujet  \
# 0              False                              False     False   False
# 1              False                              False     False   False
# 2              False                              False     False   False
# 3              False                              False     False   False
# 4              False                              False     False   False
#
#    Vistara  Vistara Premium economy
# 0    False                    False
# 1    False                    False
# 2    False                    False
# 3    False                    False
# 4    False                    False

# %%
categorical['Source'].value_counts()
# Out:
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
#Source vs Price

plt.figure(figsize=(15,15))
sns.catplot(x='Source',y='Price',data=df.sort_values('Price',ascending=False),kind='boxen')

# %%
#encoding of source column
source=pd.get_dummies(categorical['Source'],drop_first=True)
source.head()
# Out:
#    Chennai  Delhi  Kolkata  Mumbai
# 0    False  False    False   False
# 1    False  False     True   False
# 2    False   True    False   False
# 3    False  False     True   False
# 4    False  False    False   False

# %%
categorical['Destination'].value_counts()
# Out:
# Destination
# Cochin       4536
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Destination',y='Price',data=df.sort_values('Price',ascending=False))
# Out:
# <Axes: xlabel='Destination', ylabel='Price'>

# %%
#encoding of destination column
destination=pd.get_dummies(categorical['Destination'],drop_first=True)
destination.head()
# Out:
#    Cochin  Delhi  Hyderabad  Kolkata  New Delhi
# 0   False  False      False    False       True
# 1   False  False      False    False      False
# 2    True  False      False    False      False
# 3   False  False      False    False      False
# 4   False  False      False    False       True

# %%
# now work on route column
categorical['Route'].value_counts()
# Out:
# Route
# DEL → BOM → COK          2376
# BLR → DEL                1552
# CCU → BOM → BLR           979
# CCU → BLR                 724
# BOM → HYD                 621
#                          ...
# CCU → VTZ → BLR             1
# CCU → IXZ → MAA → BLR       1
# BOM → COK → MAA → HYD       1
# BOM → CCU → HYD             1
# BOM → BBI → HYD             1
# Name: count, Length: 128, dtype: int64

# %%
categorical['Route1']=categorical['Route'].str.split('→').str[0]
categorical['Route2']=categorical['Route'].str.split('→').str[1]
categorical['Route3']=categorical['Route'].str.split('→').str[2]
categorical['Route4']=categorical['Route'].str.split('→').str[3]
categorical['Route5']=categorical['Route'].str.split('→').str[4]

# %%
categorical.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info Route1 Route2 Route3 Route4 Route5
# 0         No info   BLR     DEL    NaN    NaN    NaN
# 1         No info   CCU    IXR    BBI     BLR    NaN
# 2         No info   DEL    LKO    BOM     COK    NaN
# 3         No info   CCU    NAG     BLR    NaN    NaN
# 4         No info   BLR    NAG     DEL    NaN    NaN

# %%
drop_col(categorical,'Route')

# %%
categorical.isnull().sum()
# Out:
# Airline                0
# Source                 0
# Destination            0
# Total_Stops            0
# Additional_Info        0
# Route1                 0
# Route2                 0
# Route3              3491
# Route4              9116
# Route5             10636
# dtype: int64

# %%
categorical.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Total_Stops', 'Additional_Info',
#        'Route1', 'Route2', 'Route3', 'Route4', 'Route5'],
#       dtype='object')

# %%
for i in ['Route3', 'Route4', 'Route5']:
    categorical[i].fillna('None',inplace=True)

# %%
categorical.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Total_Stops        0
# Additional_Info    0
# Route1             0
# Route2             0
# Route3             0
# Route4             0
# Route5             0
# dtype: int64

# %%
for i in categorical.columns:
    print('{} has total {} categories'.format(i,len(categorical[i].value_counts())))
# Out:
# Airline has total 12 categories
# Source has total 5 categories
# Destination has total 6 categories
# Total_Stops has total 5 categories
# Additional_Info has total 10 categories
# Route1 has total 5 categories
# Route2 has total 45 categories
# Route3 has total 30 categories
# Route4 has total 14 categories
# Route5 has total 6 categories

# %%
df.plot.hexbin(x='Arrival_Time_hour',y='Price',gridsize=15)
# Out:
# <Axes: xlabel='Arrival_Time_hour', ylabel='Price'>

# %%
# Applying label encoder
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
for i in ['Route1', 'Route2', 'Route3', 'Route4', 'Route5']:
    categorical[i]=encoder.fit_transform(categorical[i])

# %%
categorical.head()
# Out:
#        Airline    Source Destination Total_Stops Additional_Info  Route1  \
# 0       IndiGo  Banglore   New Delhi    non-stop         No info       0
# 1    Air India   Kolkata    Banglore     2 stops         No info       2
# 2  Jet Airways     Delhi      Cochin     2 stops         No info       3
# 3       IndiGo   Kolkata    Banglore      1 stop         No info       2
# 4       IndiGo  Banglore   New Delhi      1 stop         No info       0
#
#    Route2  Route3  Route4  Route5
# 0      13      29      13       5
# 1      25       1       3       5
# 2      32       4       5       5
# 3      34       3      13       5
# 4      34       8      13       5

# %%
drop_col(categorical,'Additional_Info')

# %%
categorical['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
# encoding Total stops
dict={'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3, '4 stops':4}
categorical['Total_Stops']=categorical['Total_Stops'].map(dict)

# %%
categorical['Total_Stops']
# Out:
# 0        0
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 10678    0
# 10679    0
# 10680    0
# 10681    0
# 10682    2
# Name: Total_Stops, Length: 10682, dtype: int64

# %%
drop_col(categorical,'Source')
drop_col(categorical,'Destination')
drop_col(categorical,'Airline')

# %% [markdown]
# <a id = '5.5'></a>
# <p style = "font-size : 25px; color : #34656d ; font-family : 'Comic Sans MS'; text-align : center; background-color : #fbc6a4; border-radius: 5px 5px;"><strong>After all preprocessing, Our data is ready for the modeling</strong></p>

# %%
final_df=pd.concat([categorical,Airline,source,destination,df[continuous_col]],axis=1)

# %%
final_df.head()
# Out:
#    Total_Stops  Route1  Route2  Route3  Route4  Route5  Air India  GoAir  \
# 0            0       0      13      29      13       5      False  False
# 1            2       2      25       1       3       5       True  False
# 2            2       3      32       4       5       5      False  False
# 3            1       2      34       3      13       5      False  False
# 4            1       0      34       8      13       5      False  False
#
#    IndiGo  Jet Airways  ...  New Delhi  Price  journey_day  journey_month  \
# 0    True        False  ...       True   3897           24              3
# 1   False        False  ...      False   7662            1              5
# 2   False         True  ...      False  13882            9              6
# 3    True        False  ...      False   6218           12              5
# 4    True        False  ...       True  13302            1              3
#
#    Dep_Time_hour  Dep_Time_min  Arrival_Time_hour  Arrival_Time_min  dur_hour  \
# 0             22            20                  1                10         2
# 1              5            50                 13                15         7
# 2              9            25                  4                25        19
# 3             18             5                 23                30         5
# 4             16            50                 21                35         4
#
#    dur_min
# 0       50
# 1       25
# 2        0
# 3       25
# 4       45
#
# [5 rows x 35 columns]

# %%
pd.set_option('display.max_columns',33)
final_df.head()
# Out:
#    Total_Stops  Route1  Route2  Route3  Route4  Route5  Air India  GoAir  \
# 0            0       0      13      29      13       5      False  False
# 1            2       2      25       1       3       5       True  False
# 2            2       3      32       4       5       5      False  False
# 3            1       2      34       3      13       5      False  False
# 4            1       0      34       8      13       5      False  False
#
#    IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0    True        False                 False              False
# 1   False        False                 False              False
# 2   False         True                 False              False
# 3    True        False                 False              False
# 4    True        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Trujet  Vistara  ...  Kolkata  \
# 0                              False     False   False    False  ...    False
# 1                              False     False   False    False  ...     True
# 2                              False     False   False    False  ...    False
# 3                              False     False   False    False  ...     True
# 4                              False     False   False    False  ...    False
#
#    Mumbai  Cochin  Delhi  Hyderabad  Kolkata  New Delhi  Price  journey_day  \
# 0   False   False  False      False    False       True   3897           24
# 1   False   False  False      False    False      False   7662            1
# 2   False    True  False      False    False      False  13882            9
# 3   False   False  False      False    False      False   6218           12
# 4   False   False  False      False    False       True  13302            1
#
#    journey_month  Dep_Time_hour  Dep_Time_min  Arrival_Time_hour  \
# 0              3             22            20                  1
# 1              5              5            50                 13
# 2              6              9            25                  4
# 3              5             18             5                 23
# 4              3             16            50                 21
#
#    Arrival_Time_min  dur_hour  dur_min
# 0                10         2       50
# 1                15         7       25
# 2                25        19        0
# 3                30         5       25
# 4                35         4       45
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Check For Outliers

# %%
def plot(data,col):
    fig,(ax1,ax2)=plt.subplots(2,1)
    sns.distplot(data[col],ax=ax1)
    sns.boxplot(data[col],ax=ax2)

# %%
plot(final_df,'Price')

# %% [markdown]
# ###  Handling outliers:
# #### As there is some outliers in price feature,so we replace it  with median.

# %%
final_df['Price']=np.where(final_df['Price']>=40000,final_df['Price'].median(),final_df['Price'])

# %%
plot(final_df,'Price')

# %% [markdown]
# ### Seprate the dataset in X and Y columns

# %%
X=final_df.drop('Price',axis=1)
y=df['Price']

# %% [markdown]
# # Feature Selection
# It is about finding the best feature and having good relation with independent variable
# Issue of dimensionality reduction reduces.
#
# For this we use mutual_info_classif

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mutual_info_classif(X,y)
# Out:
# array([1.91944208, 2.34617595, 3.00240754, 2.57807636, 1.7617188 ,
#        1.48948178, 0.66890345, 0.09324806, 0.62303997, 0.89233782,
#        0.0184894 , 0.53417901, 0.        , 0.3148942 , 0.        ,
#        0.21579176, 0.00800318, 0.18299334, 1.36200651, 0.82394401,
#        0.27250073, 1.37191112, 0.40546014, 0.27791908, 0.17280396,
#        0.33384841, 0.89545016, 1.65732873, 1.49031342, 1.27109358,
#        1.93216165, 1.62800091, 1.7704001 , 1.14975767])

# %%
imp = pd.DataFrame(mutual_info_classif(X,y),index=X.columns)
imp
# Out:
#                                           0
# Total_Stops                        1.888575
# Route1                             2.328780
# Route2                             2.978535
# Route3                             2.594989
# Route4                             1.708204
# Route5                             1.504191
# Air India                          0.702792
# GoAir                              0.094815
# IndiGo                             0.611454
# Jet Airways                        0.877143
# Jet Airways Business               0.000000
# Multiple carriers                  0.536610
# Multiple carriers Premium economy  0.006365
# SpiceJet                           0.302790
# Trujet                             0.001016
# Vistara                            0.204256
# Vistara Premium economy            0.000000
# Chennai                            0.170826
# Delhi                              1.385358
# Kolkata                            0.808309
# Mumbai                             0.282526
# Cochin                             1.360744
# Delhi                              0.390147
# Hyderabad                          0.284858
# Kolkata                            0.182893
# New Delhi                          0.348567
# journey_day                        0.920339
# journey_month                      1.674464
# Dep_Time_hour                      1.495796
# Dep_Time_min                       1.275666
# Arrival_Time_hour                  1.889748
# Arrival_Time_min                   1.610987
# dur_hour                           1.794234
# dur_min                            1.146789

# %%
imp.columns=['importance']
imp.sort_values(by='importance',ascending=False)
# Out:
#                                    importance
# Route2                               2.978535
# Route3                               2.594989
# Route1                               2.328780
# Arrival_Time_hour                    1.889748
# Total_Stops                          1.888575
# dur_hour                             1.794234
# Route4                               1.708204
# journey_month                        1.674464
# Arrival_Time_min                     1.610987
# Route5                               1.504191
# Dep_Time_hour                        1.495796
# Delhi                                1.385358
# Cochin                               1.360744
# Dep_Time_min                         1.275666
# dur_min                              1.146789
# journey_day                          0.920339
# Jet Airways                          0.877143
# Kolkata                              0.808309
# Air India                            0.702792
# IndiGo                               0.611454
# Multiple carriers                    0.536610
# Delhi                                0.390147
# New Delhi                            0.348567
# SpiceJet                             0.302790
# Hyderabad                            0.284858
# Mumbai                               0.282526
# Vistara                              0.204256
# Kolkata                              0.182893
# Chennai                              0.170826
# GoAir                                0.094815
# Multiple carriers Premium economy    0.006365
# Trujet                               0.001016
# Jet Airways Business                 0.000000
# Vistara Premium economy              0.000000

# %% [markdown]
# As we can see from the table, there are several features that have approx 0 value,so we should remove it after authorizing it.But for now,we are not removing it.

# %% [markdown]
# # Models

# %%
# spiliting the dataset
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=123)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
def predict(ml_model):
    print('Model is: {}'.format(ml_model))
    model= ml_model.fit(X_train,y_train)
    print("Training score: {}".format(model.score(X_train,y_train)))
    predictions = model.predict(X_test)
    print("Predictions are: {}".format(predictions))
    print('\n')
    r2score=r2_score(y_test,predictions) 
    print("r2 score is: {}".format(r2score))
          
    print('MAE:{}'.format(mean_absolute_error(y_test,predictions)))
    print('MSE:{}'.format(mean_squared_error(y_test,predictions)))
    print('RMSE:{}'.format(np.sqrt(mean_squared_error(y_test,predictions))))
     
    sns.distplot(y_test-predictions)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor

# %%
predict(RandomForestRegressor())
# Out:
# Model is: RandomForestRegressor()
# Training score: 0.9528869072681739
# Predictions are: [ 8361.928      17361.9        13831.39333333 ...  3790.37
#   5691.91       10640.688     ]
#
#
# r2 score is: 0.8416330879408314
# MAE:1083.8855091902326
# MSE:3049462.193888019
# RMSE:1746.270939427218

# %% [markdown]
# From the graph,it is clear that we predicted 84% correctly.

# %%
predict(LogisticRegression())
# Out:
# Model is: LogisticRegression()
# Training score: 0.3356348741954359
# Predictions are: [14571 15237 10844 ...  4226  7408 10262]
#
#
# r2 score is: 0.44250914423182064
# MAE:1872.6485727655593
# MSE:10734864.158165652
# RMSE:3276.4102548621186

# %%
predict(KNeighborsRegressor())
# Out:
# Model is: KNeighborsRegressor()
# Training score: 0.746380546942052
# Predictions are: [10401.2 16362.4 12933.2 ...  4210.   9073.  11232.4]
#
#
# r2 score is: 0.6544658783016435
# MAE:1700.4507253158633
# MSE:6653493.631445953
# RMSE:2579.436688784191

# %%
predict(DecisionTreeRegressor())
# Out:
# Model is: DecisionTreeRegressor()
# Training score: 0.9701124435927416
# Predictions are: [ 8996. 17024. 14571. ...  3943.  5054. 10262.]
#
#
# r2 score is: 0.7374996091123855
# MAE:1254.5940570893777
# MSE:5054622.884820361
# RMSE:2248.2488485086255

# %%
from sklearn.svm import SVR
predict(SVR())
# Out:
# Model is: SVR()
# Training score: 0.036808067930953814
# Predictions are: [8527.74272429 8268.96331405 8459.17514562 ... 8292.53786893 8453.81861376
#  8538.60587913]
#
#
# r2 score is: 0.05252926427324878
# MAE:3327.7462262427184
# MSE:18244190.9793285
# RMSE:4271.321924103649

# %%
predict(GradientBoostingRegressor())
# Out:
# Model is: GradientBoostingRegressor()
# Training score: 0.8004872305794601
# Predictions are: [ 5702.86974497 17826.76035345 12133.74946613 ...  4547.37535805
#   6959.32889786 11428.58468176]
#
#
# r2 score is: 0.8168061188758857
# MAE:1397.4505612819867
# MSE:3527522.3048542095
# RMSE:1878.1699350309625

# %% [markdown]
# # Hypertunning the model

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {
    'n_estimators' : [100, 120, 150, 180, 200,220],
    'max_features':['auto','sqrt'],
    'max_depth':[5,10,15,20],
    }

# %%
rf=RandomForestRegressor()
rf_random=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,cv=3,verbose=2,n_jobs=-1,)

rf_random.fit(X_train,y_train)

# best parameter
rf_random.best_params_
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# {'n_estimators': 120, 'max_features': 'auto', 'max_depth': 15}

# %%
# best parameter
rf_random.best_params_
# Out:
# {'n_estimators': 120, 'max_features': 'auto', 'max_depth': 15}

# %%
#predicting the values
prediction = rf_random.predict(X_test)

#distribution plot between actual value and predicted value
sns.displot(y_test-prediction)

# %%
r2_score(y_test,prediction)
# Out:
# 0.8587787493550727

# %% [markdown]
# ## After hypertuning,the accuracy increases .
